# %% [markdown]
# # EDA on Titanic Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("train_titanic - Copy.csv")

# %%
train_data.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Univariant analysis for "Survived"

# %%
sns.countplot(x = "Survived", data = train_data)
plt.show()

# %%
survived_passenger = len(train_data.Survived[train_data.Survived == 1])
dead_passenger = len(train_data) - survived_passenger
print("dead_passenger:",dead_passenger)
print("survived_people:",survived_passenger)
# Out:
# dead_passenger: 549
# survived_people: 342

# %%
print("% of people survived: ", round((survived_passenger/len(train_data))*100, 2),"%")
print("% of people Dead:",round((dead_passenger/len(train_data))*100, 2), "%" )
# Out:
# % of people survived:  38.38 %
# % of people Dead: 61.62 %

# %%
exp_values = [survived_passenger, dead_passenger]
exp_labels = ["Survived ", "Dead"]
plt.pie(exp_values, labels = exp_labels, autopct = "%.2f%%", shadow = True);

# %%
pd.crosstab(train_data.Sex, train_data.Survived, margins = True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %% [markdown]
# # Gender:Survived Vs Dead

# %%
sns.countplot(x = "Sex", hue = "Survived", data = train_data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
male_survivor = len(train_data[(train_data.Sex == "male") & (train_data.Survived == 1)] )
print("male_survivor:",male_survivor)

female_survivor = len(train_data[(train_data.Sex =="female") & (train_data.Survived == 1)])
print("female_survivor:",female_survivor)

total_passenger_male= len(train_data.Sex[train_data.Sex == "male"])
print("toal_passenger_male", total_passenger_male)

total_passenger_female = len(train_data.Sex[train_data.Sex == "female"])
print("toal_passenger_female", total_passenger_female)

percentage_male_survived = round((male_survivor/total_passenger_male)*100, 2)
percentage_female_survived = round((female_survivor/total_passenger_female)*100, 2)

print("% of male survived:",percentage_female_survived)
print("% of female Survived:",percentage_female_survived )
# Out:
# male_survivor: 109
# female_survivor: 233
# toal_passenger_male 577
# toal_passenger_female 314
# % of male survived: 74.2
# % of female Survived: 74.2

# %% [markdown]
# # Pclass:Survived Vs Dead

# %%
sns.countplot(x = "Pclass", hue = "Survived", data = train_data)
plt.title("Pclass:Survived Vs Dead")
plt.show()

# %%
pd.crosstab(train_data.Pclass, train_data.Survived, margins = True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
print("% of people survived in 1st class ticket:", round((136/216)*100, 2), ("%"))
print("% of people survived in 2nd class ticket:", round((87/184)*100, 2) , ("%"))
print("% of people survived in 3rd class ticket:", round((119/491)*100, 2), ("%"))
# Out:
# % of people survived in 1st class ticket: 62.96 %
# % of people survived in 2nd class ticket: 47.28 %
# % of people survived in 3rd class ticket: 24.24 %

# %%
pd.crosstab([train_data.Sex, train_data.Pclass], train_data.Survived, margins = True).style.background_gradient(cmap = "summer_r")
# Out:
# <style type="text/css">
# #T_33246_row0_col0, #T_33246_row1_col2, #T_33246_row4_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_33246_row0_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_33246_row0_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_33246_row1_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_33246_row1_col1, #T_33246_row4_col0 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_33246_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_33246_row2_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_33246_row2_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_33246_row3_col0 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_33246_row3_col1 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_33246_row3_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_33246_row4_col2 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_33246_row5_col0 {
#   background-color: #74ba66;
#   color: #f1f1f1;
# }
# #T_33246_row5_col1 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_33246_row5_col2 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_33246_row6_col0, #T_33246_row6_col1, #T_33246_row6_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_33246">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_33246_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_33246_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_33246_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33246_level0_row0" class="row_heading level0 row0" rowspan="3">female</th>
#       <th id="T_33246_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_33246_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_33246_row0_col1" class="data row0 col1" >91</td>
#       <td id="T_33246_row0_col2" class="data row0 col2" >94</td>
#     </tr>
#     <tr>
#       <th id="T_33246_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_33246_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_33246_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_33246_row1_col2" class="data row1 col2" >76</td>
#     </tr>
#     <tr>
#       <th id="T_33246_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_33246_row2_col0" class="data row2 col0" >72</td>
#       <td id="T_33246_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_33246_row2_col2" class="data row2 col2" >144</td>
#     </tr>
#     <tr>
#       <th id="T_33246_level0_row3" class="row_heading level0 row3" rowspan="3">male</th>
#       <th id="T_33246_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_33246_row3_col0" class="data row3 col0" >77</td>
#       <td id="T_33246_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_33246_row3_col2" class="data row3 col2" >122</td>
#     </tr>
#     <tr>
#       <th id="T_33246_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_33246_row4_col0" class="data row4 col0" >91</td>
#       <td id="T_33246_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_33246_row4_col2" class="data row4 col2" >108</td>
#     </tr>
#     <tr>
#       <th id="T_33246_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_33246_row5_col0" class="data row5 col0" >300</td>
#       <td id="T_33246_row5_col1" class="data row5 col1" >47</td>
#       <td id="T_33246_row5_col2" class="data row5 col2" >347</td>
#     </tr>
#     <tr>
#       <th id="T_33246_level0_row6" class="row_heading level0 row6" >All</th>
#       <th id="T_33246_level1_row6" class="row_heading level1 row6" ></th>
#       <td id="T_33246_row6_col0" class="data row6 col0" >549</td>
#       <td id="T_33246_row6_col1" class="data row6 col1" >342</td>
#       <td id="T_33246_row6_col2" class="data row6 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
cross_table = pd.crosstab([train_data.Sex, train_data.Pclass], train_data.Survived, normalize = "index")*100

cross_table_percentage = cross_table.applymap("{:.1f}%".format)

cross_table_style = cross_table_percentage.style

cross_table_style
# Out:
# <style type="text/css">
# </style>
# <table id="T_e75fc">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_e75fc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e75fc_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e75fc_level0_row0" class="row_heading level0 row0" rowspan="3">female</th>
#       <th id="T_e75fc_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_e75fc_row0_col0" class="data row0 col0" >3.2%</td>
#       <td id="T_e75fc_row0_col1" class="data row0 col1" >96.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e75fc_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_e75fc_row1_col0" class="data row1 col0" >7.9%</td>
#       <td id="T_e75fc_row1_col1" class="data row1 col1" >92.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e75fc_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_e75fc_row2_col0" class="data row2 col0" >50.0%</td>
#       <td id="T_e75fc_row2_col1" class="data row2 col1" >50.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e75fc_level0_row3" class="row_heading level0 row3" rowspan="3">male</th>
#       <th id="T_e75fc_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_e75fc_row3_col0" class="data row3 col0" >63.1%</td>
#       <td id="T_e75fc_row3_col1" class="data row3 col1" >36.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e75fc_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_e75fc_row4_col0" class="data row4 col0" >84.3%</td>
#       <td id="T_e75fc_row4_col1" class="data row4 col1" >15.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e75fc_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_e75fc_row5_col0" class="data row5 col0" >86.5%</td>
#       <td id="T_e75fc_row5_col1" class="data row5 col1" >13.5%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Survival Rate for Titanic passengers in different class based on Gender
#
# * 96.8 % female and 36% male survived in 1st class
# * 92.1 % female and 15.7% male survived in 2nd class
# * 50.0 % female and 13.5% male survived in 3rd class

# %%
sns.catplot(x = "Pclass", y = "Survived", hue = "Sex", data = train_data, kind = "point")

# %%
print("Age of oldest person survived:",train_data[train_data.Survived == 1]["Age"].max(),"years old")
print("Age of the youngest person survived:",train_data[train_data.Survived == 1]["Age"].min(),"years old")
print("Average age of the person who survived:",round(train_data[train_data.Survived ==1]["Age"].mean(),2), "years old")
# Out:
# Age of oldest person survived: 80.0 years old
# Age of the youngest person survived: 0.42 years old
# Average age of the person who survived: 28.34 years old

# %%
fig, axes = plt.subplots(1,2,figsize = (20,10))

sns.violinplot(x = "Pclass", y = "Age", hue = "Survived", data = train_data, split = True, ax = axes[0]);
axes[0].set_title("Pclass and Age Vs Survived")
axes[0].set_yticks(range(0,110,10));

sns.violinplot(x = "Sex", y = "Age", hue = "Survived", data = train_data, split = True, ax = axes[1]);
axes[1].set_title("sex and age Vs Survived")
axes[1].set_yticks(range(0,110,10));

# %% [markdown]
# ===========================================================

# %% [markdown]
# ===============================================================

# %% [markdown]
# # Next we filling the missing values of Age

# %%
train_data["Initial"] = 0
for i in train_data.index:
    train_data["Initial"] = train_data.Name.str.extract("([A-Za-z]+)\.")

# %%
pd.crosstab(train_data.Initial, train_data.Sex).T.style.background_gradient(cmap = "summer_r")
# Out:
# <style type="text/css">
# #T_93768_row0_col0, #T_93768_row0_col1, #T_93768_row0_col3, #T_93768_row0_col4, #T_93768_row0_col5, #T_93768_row0_col7, #T_93768_row0_col8, #T_93768_row0_col12, #T_93768_row0_col15, #T_93768_row0_col16, #T_93768_row1_col2, #T_93768_row1_col6, #T_93768_row1_col9, #T_93768_row1_col10, #T_93768_row1_col11, #T_93768_row1_col13, #T_93768_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_93768_row0_col2, #T_93768_row0_col6, #T_93768_row0_col9, #T_93768_row0_col10, #T_93768_row0_col11, #T_93768_row0_col13, #T_93768_row0_col14, #T_93768_row1_col0, #T_93768_row1_col1, #T_93768_row1_col3, #T_93768_row1_col4, #T_93768_row1_col5, #T_93768_row1_col7, #T_93768_row1_col8, #T_93768_row1_col12, #T_93768_row1_col15, #T_93768_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_93768">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_93768_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_93768_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_93768_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_93768_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_93768_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_93768_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_93768_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_93768_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_93768_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_93768_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_93768_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_93768_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_93768_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_93768_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_93768_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_93768_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_93768_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93768_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_93768_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_93768_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_93768_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_93768_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_93768_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_93768_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_93768_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_93768_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_93768_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_93768_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_93768_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_93768_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_93768_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_93768_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_93768_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_93768_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_93768_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93768_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_93768_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_93768_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_93768_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_93768_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_93768_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_93768_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_93768_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_93768_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_93768_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_93768_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_93768_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_93768_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_93768_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_93768_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_93768_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_93768_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_93768_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Initial
# 0        0         A/5 21171   7.2500   NaN        S      Mr
# 1        0          PC 17599  71.2833   C85        C     Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3        0            113803  53.1000  C123        S     Mrs
# 4        0            373450   8.0500   NaN        S      Mr
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S     Rev
# 887      0            112053  30.0000   B42        S    Miss
# 888      2        W./C. 6607  23.4500   NaN        S    Miss
# 889      0            111369  30.0000  C148        C      Mr
# 890      0            370376   7.7500   NaN        Q      Mr
#
# [891 rows x 13 columns]

# %%
train_data.Initial.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
train_data.Initial.replace(["Mlle","Mme","Ms","Dr","Major","Lady","Countess","Jonkheer","Col","Rev","Capt","Sir","Don"],
                           ["Miss","Miss","Miss","Mr","Mr","Mrs","Mrs","Other","Other","Other","Mr","Mr","Mr"], inplace = True)

# %%
train_data.Initial.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
train_data.groupby("Initial")["Age"].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial == "Master"), "Age"] = 5
train_data[(train_data.Initial == "Master") & (train_data.Age == 5)][["Initial","Age"]]     # this line is just to check if the Age for missing master age were replace with 5 ?
# Out:
#     Initial  Age
# 65   Master  5.0
# 159  Master  5.0
# 176  Master  5.0
# 709  Master  5.0

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial == "Miss"), "Age"] = 22
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial == "Mr"), "Age"] = 33
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial == "Mrs"), "Age"] = 36
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial == "Other"), "Age"] =46

# %%
# checking of the missing age foe Miss has been replaced with 22 or not?

train_data.loc[(train_data.Initial == "Miss") & (train_data.Age == 22), ["Initial","Age"]].head()
# Out:
#     Initial   Age
# 28     Miss  22.0
# 32     Miss  22.0
# 47     Miss  22.0
# 82     Miss  22.0
# 109    Miss  22.0

# %%
train_data.Age.isnull().any()
# Out:
# False

# %%
fig, axes = plt.subplots(1,2,figsize = (20,10))
train_data[train_data.Survived == 0].Age.plot.hist(ax = axes[0],bins = 20,edgecolor = "black", color = "red")
x1 = list(range(0,85,5))
axes[0].set_xticks(x1)
axes[0].set_title("Death = 0")


train_data[train_data["Survived"] == 1].Age.plot.hist(ax = axes[1],bins = 20, edgecolor = "black", color = "green")
axes[1].set_xticks(range(0,85,5))
axes[1].set_title("Survived = 1")
# Out:
# Text(0.5, 1.0, 'Survived = 1')

# %% [markdown]
# ========================================================================

# %% [markdown]
# # SibSP Vs Survived

# %%
pd.crosstab(train_data.SibSp, train_data.Survived, margins = True).style.background_gradient("summer_r")
# Out:
# <style type="text/css">
# #T_7f808_row0_col0 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_7f808_row0_col1 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_7f808_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_7f808_row1_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_7f808_row1_col1 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_7f808_row1_col2 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_7f808_row2_col0, #T_7f808_row4_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_7f808_row2_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_7f808_row2_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_7f808_row3_col0, #T_7f808_row3_col2, #T_7f808_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_7f808_row3_col1, #T_7f808_row4_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_7f808_row5_col0, #T_7f808_row5_col1, #T_7f808_row5_col2, #T_7f808_row6_col0, #T_7f808_row6_col1, #T_7f808_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7f808_row7_col0, #T_7f808_row7_col1, #T_7f808_row7_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f808">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_7f808_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7f808_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7f808_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f808_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f808_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_7f808_row0_col1" class="data row0 col1" >210</td>
#       <td id="T_7f808_row0_col2" class="data row0 col2" >608</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f808_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_7f808_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_7f808_row1_col2" class="data row1 col2" >209</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f808_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_7f808_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_7f808_row2_col2" class="data row2 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f808_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_7f808_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_7f808_row3_col2" class="data row3 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f808_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_7f808_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_7f808_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f808_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_7f808_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_7f808_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_7f808_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_7f808_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_7f808_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_7f808_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_7f808_row7_col0" class="data row7 col0" >549</td>
#       <td id="T_7f808_row7_col1" class="data row7 col1" >342</td>
#       <td id="T_7f808_row7_col2" class="data row7 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
cross_table = pd.crosstab(train_data.SibSp, train_data.Survived, normalize = "index", margins = True)*100

# %%
cross_table = cross_table.applymap("{:.1f}%".format)
cross_table
# Out:
# Survived       0      1
# SibSp
# 0          65.5%  34.5%
# 1          46.4%  53.6%
# 2          53.6%  46.4%
# 3          75.0%  25.0%
# 4          83.3%  16.7%
# 5         100.0%   0.0%
# 8         100.0%   0.0%
# All        61.6%  38.4%

# %%
fig, axes = plt.subplots(1,2,figsize = (30,10))
sns.barplot(x = "SibSp", y = "Survived",data = train_data, ax =  axes[0])
axes[0].set_title("SibSp Vs Survived in Barplot")

sns.pointplot(x = "SibSp", y = "Survived", data = train_data, ax = axes[1] )
axes[1].set_title("SibSp Vs Survived in pointplot");

# %%
pd.crosstab(train_data.SibSp, train_data.Pclass).style.background_gradient("summer_r")
# Out:
# <style type="text/css">
# #T_e0474_row0_col0, #T_e0474_row0_col1, #T_e0474_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_e0474_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_e0474_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_e0474_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_e0474_row2_col0, #T_e0474_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_e0474_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_e0474_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_e0474_row3_col0, #T_e0474_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_e0474_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_e0474_row4_col0, #T_e0474_row4_col1, #T_e0474_row5_col0, #T_e0474_row5_col1, #T_e0474_row5_col2, #T_e0474_row6_col0, #T_e0474_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e0474_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_e0474">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_e0474_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e0474_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_e0474_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0474_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0474_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_e0474_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_e0474_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_e0474_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0474_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_e0474_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_e0474_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_e0474_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0474_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_e0474_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_e0474_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e0474_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0474_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_e0474_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_e0474_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e0474_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0474_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_e0474_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_e0474_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_e0474_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0474_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_e0474_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_e0474_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e0474_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_e0474_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_e0474_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_e0474_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
cross_table = pd.crosstab(train_data.SibSp, train_data.Pclass, normalize = "index", margins = True) *100
cross_table = cross_table.applymap("{:.1f}%".format)
cross_table
# Out:
# Pclass      1      2       3
# SibSp
# 0       22.5%  19.7%   57.7%
# 1       34.0%  26.3%   39.7%
# 2       17.9%  28.6%   53.6%
# 3       18.8%   6.2%   75.0%
# 4        0.0%   0.0%  100.0%
# 5        0.0%   0.0%  100.0%
# 8        0.0%   0.0%  100.0%
# All     24.2%  20.7%   55.1%
